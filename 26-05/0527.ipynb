# %% [markdown]
# ## Hidden Gem 프로젝트 진행 상황 (Day 1 - 2026-05-28)
# ✅ 완료
# 추천 엔진 v5 + 24개 테스트
# Redis/CostGuard/Rate Limit/Sentry/Discord/DB백업
# 행동 로그 (UserAction) 인프라
# Phase 1.5 완료
# 프론트엔드 v2 (URL 검색, Skeleton, ErrorState)
# PRD v4.2.3 (100/100)
# 🟡 진행 중 - Google OAuth (90%)
# ✅ Django settings.py, urls.py, views.py, adapters 코드
# ✅ Google Cloud Console 클라이언트 ID 발급
# ✅ Django migrate 완료
# ✅ SocialApp DB 등록 (Sites=['localhost:8001'])
# ✅ allauth 65.17.0
# ✅ .env 정리 (Docker 기본 + 로컬 주석)
# ✅ docker-compose.yml 포트 8001:8000 정상화
# ✅ urls.py에서 GoogleLoginCallbackView 라우트 삭제
# ✅ views.py에서 GoogleLoginCallbackView 클래스 삭제
# 🔴 로그인 테스트 미완료 (redirect_uri_mismatch 에러)
# 🎯 발견된 진짜 원인
# urls.py에 GoogleLoginCallbackView가 name='google_callback'으로 등록됨
# allauth.urls 안에도 같은 name 존재
# Django는 마지막 등록 우선 → allauth의 reverse('google_callback')이 /api/auth/google/callback/ 반환
# → Google에 잘못된 redirect_uri 전송
# → 4개 URI 등록했지만 매번 실패
# ✅ 해결 적용 (방금)
# urls.py: GoogleLoginCallbackView 라우트 삭제
# views.py: GoogleLoginCallbackView 클래스 삭제
# Django 재시작 완료
# 다음: 시크릿 창에서 재시도
# 📂 파일 위치# 📅 2026-MM-DD (요일) 개발 노트 : [오늘 작업할 핵심 주제]
#
# ## 🎯 오늘의 목표
# - [ ] [오늘 달성할 구체적인 작업 1]
# - [ ] [오늘 달성할 구체적인 작업 2]
#
# ## 🛠 진행 상황 및 핵심 기록
# - [실제 수행한 작업 내역 요약]
# - [기억해야 할 API 엔드포인트, 데이터 구조, 변수명 등 메모]
#
# ## 🚨 트러블슈팅 (문제 및 해결)
# - **문제:** [마주친 에러 메시지나 막힌 부분]
# - **원인:** [문제가 발생한 이유 분석]
# - **해결:** [어떤 코드를 수정했는지, 혹은 어떻게 해결했는지 기록]
#
# ## 💡 인사이트 및 다음 할 일
# - **배운 점:** [오늘 새롭게 알게 된 원리나 팁]
# - **다음 할 일:** [다음 파일에서 이어서 진행할 작업]
