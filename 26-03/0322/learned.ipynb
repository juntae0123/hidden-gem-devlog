# %% [markdown]
# #0322 AI 엔진  + Frontend 구축 일지

# %% [markdown]
# 1. 오늘 내가 한 일 (AI + Frontend)
# AI 실험실 세팅: pip로 pandas, scikit-learn, sentence-transformers 설치 완료.
#
# 의미: 게임 데이터를 분석하고, 문장의 의미를 숫자로 바꿔서 유사도를 계산할 준비 끝.
#
# 웹 엔진 장착: Node.js 설치해서 웹 서비스 돌릴 환경 만듦.
#
# 본진(Web) 생성: Next.js로 hidden-gem-web 폴더 파고 메인 화면 코딩.
#
# 버전 관리: 에러 다 잡고 오늘 치 작업 git commit 완료.

# %%
2. 우리가 쓴 AI 도구들 (핵심 요약)
Pandas: 수백 개 게임 데이터를 엑셀처럼 편하게 다루는 도구.

Sentence-Transformers: "위쳐 같은 게임"이라는 문장을 AI가 이해하는 **'벡터(숫자)'**로 변환해주는 핵심 모델.

Scikit-learn: 변환된 숫자들 사이의 거리를 계산해서 가장 비슷한 게임을 찾아주는 수학 선생님.

# %%
3. 코드의 의미 (왜 두 번 작업해?)
Python (실험실): 데이터를 가공하고 AI 모델 성능을 테스트하는 곳. (데이터 사이언티스트 모드)

Next.js (본진): AI가 찾은 결과를 유저에게 예쁘게 보여주는 곳. (웹 개발자 모드)

결국 이 둘을 합쳐서 "유저 질문 -> AI 분석 -> 결과 출력" 구조를 만드는 게 목표!
