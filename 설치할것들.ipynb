# %% [markdown]
# 주피터 노트북(ipynb) 및 마크다운 정리 내용
# 아래 내용을 복사해서 .ipynb 파일의 마크다운 셀에 넣거나, 메모장에 저장해두세요.
#
# 🏗️ Hidden Gem Project: 환경 재설치 가이드 (자리 이동용)
# 1. 엔진 및 기초 도구 설치 (가장 먼저 할 일)
# 컴퓨터 자체가 바뀌면 이 도구들이 없을 확률이 높습니다.
#
# Node.js 설치: https://nodejs.org/ (LTS 버전) - npx, npm 명령어를 쓰기 위해 필수입니다.
#
# VS Code 익스텐션: (로그인 기능을 쓰면 자동으로 따라오지만, 안 되면 설치)
#
# Python
#
# ESLint
#
# Tailwind CSS IntelliSense
#
# 2. 코드 가져오기 (Git)
# 터미널(Git Bash)을 열고 작업 폴더로 이동한 뒤:

# %%
git clone <본인의-깃허브-저장소-주소>
cd Hidden-Gem-project/hidden-gem-web

# %% [markdown]
# 3. 라이브러리 재설치 (핵심!)
# .gitignore 설정 때문에 node_modules 폴더(라이브러리 뭉치)는 깃허브에 올라가지 않습니다. 그래서 새 자리에서는 이걸 다시 받아야 합니다.

# %%
# 본진 폴더(hidden-gem-web) 안에서 실행
npm install

# %% [markdown]
# 4. 파이썬 가상환경 및 AI 라이브러리 (실험실용)
# 만약 파이썬 실험실(ipynb)도 돌려야 한다면:

# %% [markdown]
# 3. 라이브러리 재설치 (핵심!)
# .gitignore 설정 때문에 node_modules 폴더와 AI 라이브러리들은 깃허브에 올라가지 않습니다. 새 자리에서는 이걸 무조건 다시 받아야 합니다.
#
# (1) 웹 부품 설치 (본진 폴더 안에서 실행)
# Bash
# npm install
# (2) AI 부품 설치 (실험실용)
# Bash
# # 필수 라이브러리 한 번에 설치
# pip install pandas scikit-learn sentence-transformers ipykernel
# 4. 실행 확인
# 터미널에서 아래 명령어로 서버를 켜고 화면이 나오는지 확인합니다.

# %%
# 가상환경 생성 및 활성화
python -m venv venv
source venv/Scripts/activate  # 윈도우 기준

# 필수 라이브러리 설치
pip install pandas scikit-learn sentence-transformers ipykernel

# %% [markdown]
# 5. 실행 확인

# %%
npm run dev

# %% [markdown]
# # 🚀 다른 컴퓨터에서 작업 재개하기 (환경 복구)
#
# ### 1. 환경 점검 (컴퓨터 사양 확인)
# 터미널을 열고 아래 명령어로 엔진이 있는지 확인합니다.
# - `node -v` (버전이 안 뜨면 Node.js 설치 필요)
# - `git --version` (안 뜨면 Git 설치 필요)
#
# ### 2. 코드 불러오기
# 내 프로젝트 폴더로 이동 후:
# - `git pull origin master` (최신 코드 가져오기)
#
# ### 3. 부품 조립 (매우 중요 ⭐)
# 프로젝트의 본진(`hidden-gem-web`) 폴더로 이동해서 실행:
# - `npm install`
#   *(이걸 해야 node_modules 폴더가 생기면서 에러가 사라집니다)*
#
# ### 4. 서버 가동
# - `npm run dev`

# %% [markdown]
# 🏗️ Hidden Gem Project: 환경 재설치 가이드 (AI + Web 통합)
# 1. 엔진 및 기초 도구 설치
# 컴퓨터 자체가 바뀌면 이 도구들이 없을 확률이 높습니다.
#
# Node.js 설치: https://nodejs.org/ (웹 서버 실행용)
#
# Python 설치: https://www.python.org/ (AI 로직 실행용)
#
# 2. 코드 가져오기 (Git)
# 터미널(Git Bash)을 열고 내 프로젝트 폴더로 이동:
#
# Bash
# git clone <본인의-깃허브-저장소-주소>
# cd Hidden-Gem-project/hidden-gem-web
# 3. 라이브러리 재설치 (가장 중요 ⭐)
# 깃허브에 없는 무거운 부품들을 새 컴퓨터에 다시 다운로드합니다.
#
# (1) AI 부품 설치 (Python Libraries)
# 이걸 안 깔면 AI 추천 엔진이 돌아가지 않습니다.
#
# Bash
# # pandas: 데이터 관리 / scikit-learn: 유사도 계산 / sentence-transformers: 문장 이해 AI
# pip install pandas scikit-learn sentence-transformers ipykernel
# (2) 웹 부품 설치 (Node.js Packages)
# 본진 폴더(hidden-gem-web) 안에서 실행하세요.
#
# Bash
# npm install
# 4. 실행 및 서버 가동
# Bash
# # 터미널에서 아래 명령어로 웹 화면 띄우기
# npm run dev
# 🚀 자리 이동 시 1분 퀵 체크리스트
# 환경 확인: 터미널에 node -v, python --version 쳐서 숫자 나오는지 확인.
#
# 코드 동기화: git pull origin master
#
# 부품 조립:
#
# npm install (웹 부품)
#
# pip install pandas scikit-learn sentence-transformers (AI 부품)
#
# 가동: npm run dev
